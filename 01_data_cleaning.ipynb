# %%
# Data manipulation
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Display settings
pd.set_option('display.max_columns', None)

# Plot style
sns.set_style("whitegrid")

# %%
df = pd.read_csv("Motor_Insurance_Dataset.csv")

df.head()
# Out:
#   INSURANCE TYPE VEHICLE TYPE VEHICLE USE VEHICLE MAKE VEHICLE MODEL  \
# 0  Comprehensive          Car     Private       Toyota         Prius
# 1    Third Party         Bike     Private        Honda           CBR
# 2  Comprehensive          Car     Private       Nissan         Sunny
# 3    Third Party          Car     Private         Ford    Ranger XLT
# 4  Comprehensive        Truck     Private         Tata    Dimo Batta
#
#    VEHICLE MAKE YEAR  SUM INSURED  POLICY PREMIUM
# 0               2011    6495000.0        88691.98
# 1               2004    1050000.0         1200.00
# 2               1999    2450000.0        35266.26
# 3               2018   24000000.0         3500.00
# 4               2013    1800000.0        35278.05

# %%
df.shape
# Out:
# (3998, 8)

# %%
df.columns
# Out:
# Index(['INSURANCE TYPE', 'VEHICLE TYPE', 'VEHICLE USE', 'VEHICLE MAKE',
#        'VEHICLE MODEL', 'VEHICLE MAKE YEAR', 'SUM INSURED', 'POLICY PREMIUM'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   INSURANCE TYPE     3998 non-null   object
#  1   VEHICLE TYPE       3998 non-null   object
#  2   VEHICLE USE        3998 non-null   object
#  3   VEHICLE MAKE       3998 non-null   object
#  4   VEHICLE MODEL      3998 non-null   object
#  5   VEHICLE MAKE YEAR  3998 non-null   int64
#  6   SUM INSURED        3998 non-null   float64
#  7   POLICY PREMIUM     3998 non-null   float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 250.0+ KB

# %%
df.isnull().sum()
# Out:
# INSURANCE TYPE       0
# VEHICLE TYPE         0
# VEHICLE USE          0
# VEHICLE MAKE         0
# VEHICLE MODEL        0
# VEHICLE MAKE YEAR    0
# SUM INSURED          0
# POLICY PREMIUM       0
# dtype: int64

# %%
df.describe()
# Out:
#        VEHICLE MAKE YEAR   SUM INSURED  POLICY PREMIUM
# count        3998.000000  3.998000e+03    3.998000e+03
# mean         2010.538269  7.002169e+06    5.203113e+04
# std             8.650869  1.259108e+07    1.328528e+05
# min          1953.000000  7.000000e+04    1.200000e+03
# 25%          2007.000000  8.300000e+05    3.500000e+03
# 50%          2013.000000  2.775000e+06    4.650000e+03
# 75%          2016.000000  7.997500e+06    4.451179e+04
# max          2024.000000  1.450000e+08    2.700000e+06

# %%
current_year = 2025

df["VEHICLE AGE"] = current_year - df["VEHICLE MAKE YEAR"]

df["PREMIUM RATE"] = df["POLICY PREMIUM"] / df["SUM INSURED"]

df.head()
# Out:
#   INSURANCE TYPE VEHICLE TYPE VEHICLE USE VEHICLE MAKE VEHICLE MODEL  \
# 0  Comprehensive          Car     Private       Toyota         Prius
# 1    Third Party         Bike     Private        Honda           CBR
# 2  Comprehensive          Car     Private       Nissan         Sunny
# 3    Third Party          Car     Private         Ford    Ranger XLT
# 4  Comprehensive        Truck     Private         Tata    Dimo Batta
#
#    VEHICLE MAKE YEAR  SUM INSURED  POLICY PREMIUM  VEHICLE AGE  PREMIUM RATE
# 0               2011    6495000.0        88691.98           14      0.013655
# 1               2004    1050000.0         1200.00           21      0.001143
# 2               1999    2450000.0        35266.26           26      0.014394
# 3               2018   24000000.0         3500.00            7      0.000146
# 4               2013    1800000.0        35278.05           12      0.019599

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["POLICY PREMIUM"], bins=50)

plt.title("Distribution of Policy Premium")
plt.xlabel("Premium")
plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["SUM INSURED"], bins=50)

plt.title("Distribution of Sum Insured")
plt.xlabel("Insured Value")

plt.show()

# %%
df.to_csv("motor_insurance_clean.csv", index=False)
